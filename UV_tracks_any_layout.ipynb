# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.constants
from IPython.display import HTML 
HTML('../style/course.css') #apply general CSS

import math

# %%
from IPython.display import Image

# %%
HTML('../style/code_toggle.html')
# Out:
# ../style/code_toggle.html

# %% [markdown]
# 1.

# %%
RA_rad = (np.pi/12) * np.array([5. + 30./60, 5 + 55.0/60 + 10.3053/3600, 5 + 14/60.0 + 32.272/3600])
DEC_rad = (np.pi/180)*np.array([0, 7 + 24/60.0 + 25.42/3600, -8 + 12/60.0 + 5.898/3600])
RA_delta_rad = RA_rad-RA_rad[0] 

l = np.cos(DEC_rad) * np.sin(RA_delta_rad)
m = (np.sin(DEC_rad) * np.cos(DEC_rad[0]) - np.cos(DEC_rad) * np.sin(DEC_rad[0]) * np.cos(RA_delta_rad))
print("l (degrees) = ", l*(180./np.pi))
L_deg = l*(180./np.pi)
M_deg = m*(180./np.pi)
print("m (degrees) = ", m*(180./np.pi))
Flux_sources_labels = np.array(["", "Betelgeuse", "Rigel"])
# Out:
# l (degrees) =  [ 0.          6.22788696 -3.82687913]
# m (degrees) =  [ 0.          7.38644635 -7.77430634]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.xlim([-7., 7.])
plt.ylim([-12., 12.])
plt.xlabel("$l$ [degrees]")
plt.ylabel("$m$ [degrees]")
plt.plot(l[0], m[0], "bx")
plt.plot(l[1:]*(180/np.pi), m[1:]*(180/np.pi), "ro")
counter = 1
for xy in zip(l[1:]*(180/np.pi)+0.25, m[1:]*(180/np.pi)+0.25):                                              
    ax.annotate(Flux_sources_labels[counter], xy=xy, textcoords='offset points',horizontalalignment='right',
                verticalalignment='bottom')  
    counter = counter + 1

plt.grid()
# Out:
# /home/jason/.local/lib/python3.6/site-packages/matplotlib/text.py:2178: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   warnings.warn("You have used the `textcoords` kwarg, but not "

# %% [markdown]
# 2.

# %%
# dc = math.sqrt(L_deg[0]**2 + M_deg[0]**2)
db = math.sqrt(l[1]**2 + m[1]**2)
print("disance ", db)
# Out:
# disance  0.16862641579958426

# %% [markdown]
# 3.

# %%
# tc = math.asin(math.sqrt(L_deg[0]**2 + M_deg[0]**2))
tb = math.asin(math.sqrt(l[1]**2 + m[1]**2)) 
print("angular disance (degrees)", tb)
# Out:
# angular disance (degrees) 0.16943596288833088

# %% [markdown]
# 4.
# In a spherical right triangle, let C denote the length of the side opposite the right angle. Let A and B denote the lengths of the other two sides.  Let R denote the radius of the sphere.  Then, we can use the following formula: cos(C/R) = cos(A/R)*cos(B/R).

# %%
cr = math.cos(tb)
abr = math.cos(l[1]) * math.cos(m[1])
print(cr, abr)
# Out:
# 0.9856800352521023 0.9858488576640116

# %% [markdown]
# 5

# %% [markdown]
# 6.

# %% [markdown]
# Question 2

# %%
RA_sources = np.array([-4 + 44/60.0 + 6.686/3600, -4 + 44/60.0 + 6.686/3600])
DEC_sources = np.array([-74 + 39/60.0 + 37.481/3600, -73 + 39.0/60.0 + 37.298/3600])
Flux_sources_labels = np.array(["1 Jy","0.2 Jy"])
Flux_sources = np.array([1,0.2]) #in Jy
step_size = 200
print("Phase center     Source 1")
print("RA="+str(RA_sources))
print("DEC="+str(DEC_sources))
# Out:
# Phase center     Source 1
# RA=[-3.26480944 -3.26480944]
# DEC=[-73.33958861 -72.33963944]

# %%
RA_rad = np.array(RA_sources)*(np.pi/12)
DEC_rad = np.array(DEC_sources)*(np.pi/180)
RA_delta_rad = RA_rad-RA_rad[0]

l = np.cos(DEC_rad)*np.sin(RA_delta_rad)
m = (np.sin(DEC_rad)*np.cos(DEC_rad[0])-np.cos(DEC_rad)*np.sin(DEC_rad[0])*np.cos(RA_delta_rad))
print("l=",l)
print("m=",m)

point_sources = np.zeros((len(RA_sources),3))
point_sources[:,0] = Flux_sources
point_sources[:,1] = l[1:]
point_sources[:,2] = m[1:]
# Out:
# l= [0. 0.]
# m= [0.         0.01745152]

# %%
# %matplotlib inline
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.xlim([-4,4])
plt.ylim([-4,4])
plt.xlabel("$l$ [degrees]")
plt.ylabel("$m$ [degrees]")
plt.plot(l[0],m[0],"bx")
plt.plot(l[1:]*(180/np.pi),m[1:]*(180/np.pi),"ro") 
counter = 1
for xy in zip(l[1:]*(180/np.pi)+0.25, m[1:]*(180/np.pi)+0.25):                                              
    ax.annotate(Flux_sources_labels[counter], xy=xy, textcoords='offset points',horizontalalignment='right',
                verticalalignment='bottom')  
    counter = counter + 1
        
plt.grid()

# %% [markdown]
# $A_k = flux$
# $I(l,m)=A_k𝛿(l−l_0, m−m_0)$
# $I(l,m) = 1𝛿(l,m) + 0.2𝛿(l, m−0.01745152)$

# %% [markdown]
# $\mathcal{F\{I(l,m)\}} = \sum_{k=0}^k{A_ke^{-2\pi i (ul_k + vm_k)}}$
# $= e^{-2\pi i (0) }+ 0.2e^{-2\pi i (0 + v0.01745152)}$
# $= 1 + 0.2e^{-2\pi i (v0.01745152)}$

# %% [markdown]
# $e^{ix} = cos(x) + isin(x)$
# $1+0.2𝑒−2\pi𝑖(𝑣0.01745152) = 1 + 0.2cos(2\pi(𝑣0.01745152)) + 0.2isin(2\pi(𝑣0.01745152))$

# %% [markdown]
# Question 3

# %%
antennas = np.array([[ 25.095, -9.095,  0.045], #LOADING KAT7 ANTENNAS
            [ 90.284, 26.380, -0.226],
            [  3.985, 26.839,  0.000],
            [-21.605, 25.494,  0.019],
            [-38.272, -2.582,  0.391],
            [-61.595,-79.699,  0.792],
            [-87.988, 75.754,  0.138]])

# %%
plt.scatter(antennas[:,0], antennas[:,1])
plt.grid(True)
plt.xlabel('E-W [m]')
plt.ylabel('N-S [m]')
plt.title('KAT7 Array Layout')
plt.show()

# %%
b12 = antennas[2] - antennas[0]
ant1 = antennas[0]
ant2 = antennas[2]
print(b12)
# Out:
# [-21.11   35.934  -0.045]

# %%
D12 = math.sqrt(np.sum((b12)**2))
print(D12)
# Out:
# 41.675970066694305

# %%
# E = math.asin(b12[2] / D12) 
# print("E",E * (180/np.pi))
# AA = math.acos(b12[1] / (D12 * math.cos(E)))
# N = np.array([0,1])
# a = np.array([b12[0], b12[1]])
# A = math.acos(np.dot(N,a) / (np.linalg.norm(a) * np.linalg.norm(N)))
# print("A",A * (180/np.pi), AA* (180/np.pi))
# # Apparantly both methods for calculating Azimuth work...

A = np.arctan2(b12[0],b12[1])
E = np.arcsin(b12[2]/D12)
print(E*(180/np.pi),A*(180/np.pi))
from mpl_toolkits.mplot3d import Axes3D
import plotBL
# Out:
# -0.06186564043890538 -30.43278368565998

# %%
la = (np.pi/180)*(-30 - 43.0/60 - 17.34/3600)
# %matplotlib nbagg
plt.figure()
plotBL.sphere(ant1,ant2,A,E,D12,la)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="720">

# %%
B12 = np.array([D12 * (math.cos(la)*math.sin(E) - math.sin(la) * math.cos(E)*math.cos(A)),
                D12 * (math.cos(E)*math.sin(A)),
                D12 * (math.sin(la)*math.sin(E) + math.cos(la) * math.cos(E)*math.cos(A))])
print(B12)
# Out:
# [ 18.31874852 -21.11        30.91403943]

# %%
# Observation parameters
c = scipy.constants.c                                        # Speed of light
f = 1.4e9                                     # Frequency
lam = c/f                                      # Wavelength 
dec = (np.pi/180)*(-74.0 - 39.0/60 - 37.481/3600)     # Declination

time_steps = 600                               # time steps
h = np.linspace(-4,4,num=time_steps)*np.pi/12  # Hour angle window
print(lam)
# Out:
# 0.21413747

# %%
X = B12[0]
Y = B12[1]
Z = B12[2]

# %%
u = lam**(-1)*(np.sin(h)*X+np.cos(h)*Y)
v = lam**(-1)*(-np.sin(dec)*np.cos(h)*X+np.sin(dec)*np.sin(h)*Y+np.cos(dec)*Z)
w = lam**(-1)*(np.cos(dec)*np.cos(h)*X-np.cos(dec)*np.sin(h)*Y+np.sin(dec)*Z)
# %matplotlib nbagg
plt.figure()
plotBL.UV(u,v,w)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# (6) Calculate $\sqrt{X_{12}^2 + Y_{12}^2}\lambda^{-1}$, $|\sin \delta_0| \sqrt{X_{12}^2 + Y_{12}^2}\lambda^{-1}$ and $\cos\delta_0 Z_{12}\lambda^{-1}$ [3].

# %%
# %matplotlib inline
from matplotlib.patches import Ellipse

# parameters of the UVtrack as an ellipse
# X = B12[0]
# Y = B12[1]
# Z = B12[2]
a=np.sqrt(X**2+Y**2)/lam # major axis  
b=a*np.sin(dec)              # minor axis
v0=(Z/lam)*np.cos(dec)     # center of ellipse
print(a,b,v0)

plotBL.UVellipse(u,v,w,a,b,v0)
# Out:
# 130.52414399404006 -125.87420370654006 38.1903408576521

# %%
H0 = -4 
trans = np.array([[math.sin(H0), math.cos(H0), 0], [-math.sin(dec) * math.cos(H0), math.sin(dec)*math.sin(H0), math.cos(dec)]])
uv_12 = 1/lam * np.matmul(trans, B12)
print(uv_12)

H1 = 4
trans = np.array([[math.sin(H1), math.cos(H1), 0], [-math.sin(dec) * math.cos(H1), math.sin(dec)*math.sin(H1), math.cos(dec)]])
uv_12 = 1/lam * np.matmul(trans, B12)
print(uv_12)
# Out:
# [129.17912697  56.21422899]
# [ -0.30474701 -87.68351976]

# %%
H = np.linspace(-4,4,600)*(np.pi/12) #Hour angle in radians
d = 1/lam * B12[1] 
u_d = d*np.cos(H)
v_d = d*np.sin(H)*np.sin(dec)
u_track = u_d
v_track = v_d
z = np.zeros(u_track.shape).astype(complex)       
plt.figure()

s = point_sources.shape
for counter in range(1, s[0]+1):
    A_i = point_sources[counter-1,0]
    l_i = point_sources[counter-1,1]
    m_i = point_sources[counter-1,2]
    z += A_i*np.exp(-1*2*np.pi*1j*(u_track*l_i+v_track*m_i))
plt.subplot(121)
plt.plot(z.real)
plt.xlabel("Timeslots")
plt.ylabel("Jy")
plt.title("Real: sampled visibilities")

plt.subplot(122)
plt.plot(z.imag)
plt.xlabel("Timeslots")
plt.ylabel("Jy")
plt.title("Imag: sampled visibilities")
# Out:
# Text(0.5, 1.0, 'Imag: sampled visibilities')

# %%
# delta = 60*(np.pi/180) #Declination in degrees
u = np.linspace(-1*(np.amax(np.abs(u_d)))-10, np.amax(np.abs(u_d))+10, num=step_size, endpoint=True)
v = np.linspace(-1*(np.amax(abs(v_d)))-10, np.amax(abs(v_d))+10, num=step_size, endpoint=True)   
uu, vv = np.meshgrid(u, v)
zz = np.zeros(uu.shape).astype(complex)
s = point_sources.shape 
for counter in range(1, s[0]+1):
    A_i = point_sources[counter-1,0]
    l_i = point_sources[counter-1,1]
    m_i = point_sources[counter-1,2]
    zz += A_i*np.exp(-2*np.pi*1j*(uu*l_i+vv*m_i))
zz = zz[:,::-1]

# %%
plt.figure()
plt.subplot(121)
plt.imshow(zz.real,extent=[-1*(np.amax(np.abs(u_d)))-10, np.amax(np.abs(u_d))+10,-1*(np.amax(abs(v_d)))-10, \
                           np.amax(abs(v_d))+10])
plt.plot(u_d,v_d,"k")
plt.xlim([-1*(np.amax(np.abs(u_d)))-10, np.amax(np.abs(u_d))+10])
plt.ylim(-1*(np.amax(abs(v_d)))-10, np.amax(abs(v_d))+10)
plt.xlabel("u")
plt.ylabel("v")
plt.title("Real part of visibilities")

plt.subplot(122)
plt.imshow(zz.imag,extent=[-1*(np.amax(np.abs(u_d)))-10, np.amax(np.abs(u_d))+10,-1*(np.amax(abs(v_d)))-10, \
                           np.amax(abs(v_d))+10])
plt.plot(u_d,v_d,"k")
plt.xlim([-1*(np.amax(np.abs(u_d)))-10, np.amax(np.abs(u_d))+10])
plt.ylim(-1*(np.amax(abs(v_d)))-10, np.amax(abs(v_d))+10)
plt.xlabel("u")
plt.ylabel("v")
plt.title("Imaginary part of visibilities")
# Out:
# Text(0.5, 1.0, 'Imaginary part of visibilities')
